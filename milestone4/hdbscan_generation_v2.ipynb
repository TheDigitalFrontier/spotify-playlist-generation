# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from os import listdir
from os.path import isfile, join

import scipy.sparse

import time

sns.set()

# %%
# %matplotlib inline

# %% [markdown]
# ## 1. Load prepared data

# %% [markdown]
# Load song master table and reduced table

# %%
# Load master song table with added metadata
master = pd.read_pickle('../data/master200.pkl')
master_reduced = pd.read_pickle('../data/final/master_reduced.pkl')

song_ids = master_reduced.index.values
cont_feats = list(master_reduced.drop(['artist_name', 'album_name'], 1).columns)

# %%
master.head(3)
# Out:
#                                artist_name  \
# song_id
# 0        Sidney Bechet's Blue Note Jazzmen
# 159583                       Sidney Bechet
# 271702                       Sidney Bechet
#
#                                     artist_uri  \
# song_id
# 0        spotify:artist:2XouUSO0EAJ9gMMoHiXqMt
# 159583   spotify:artist:1RsmXc1ZqW3WBs9iwxiSwk
# 271702   spotify:artist:1RsmXc1ZqW3WBs9iwxiSwk
#
#                                      track_name  \
# song_id
# 0                                Muskrat Ramble
# 159583                             Blue Horizon
# 271702   Blame It On The Blues - Alternate Take
#
#                                     album_uri  duration_ms     album_name  \
# song_id
# 0        spotify:album:04hQBJ7YSuNnZ0nbuXNYbY       220293  Jazz Classics
# 159583   spotify:album:04hQBJ7YSuNnZ0nbuXNYbY       264933  Jazz Classics
# 271702   spotify:album:04hQBJ7YSuNnZ0nbuXNYbY       175893  Jazz Classics
#
#          count                             track_uri  danceability  energy  \
# song_id
# 0            1  spotify:track:0002yNGLtYSYtc0X6ZnFvp         0.455   0.623
# 159583       5  spotify:track:1EWPMNHfdVNJwBpG9BcxXB         0.327   0.372
# 271702       1  spotify:track:26N4Y48EjprAtvlY6yWZTA         0.574   0.606
#
#          ...  instrumentalness  liveness  valence    tempo  time_signature  \
# song_id  ...
# 0        ...             0.903     0.634    0.951  182.345               4
# 159583   ...             0.835     0.153    0.380   66.036               4
# 271702   ...             0.948     0.349    0.965  101.361               4
#
#                                              artist_genres  artist_popularity  \
# song_id
# 0                                                       []                 18
# 159583   ['bebop', 'big band', 'cool jazz', 'dixieland'...                 52
# 271702   ['bebop', 'big band', 'cool jazz', 'dixieland'...                 52
#
#          album_genres  album_popularity  album_release_date
# song_id
# 0                  []                37          1993-01-01
# 159583             []                37          1993-01-01
# 271702             []                37          1993-01-01
#
# [3 rows x 25 columns]

# %%
encoded_cont = np.load('../data/final/encoded_cont_5wide.npy', allow_pickle = True)

# %%
encoded_cont.shape
# Out:
# (213675, 5)

# %%
indicators = scipy.sparse.load_npz('../data/final/indicators.npz')

# %%
indicators.shape
# Out:
# (213675, 187313)

# %% [markdown]
# ## Visualise clusters with t-SNE
# Visualise clusters with t-SNE

# %%
# Data already shuffled, so we can pull a random subset of train data for visualisation
np.random.seed(42)
tsne_ind = np.random.choice(np.arange(encoded_cont.shape[0]), 10000)

# %% [markdown]
# Code heavily borrowed from:
# https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %%
from sklearn.manifold import TSNE
time_start = time.time()
tsne = TSNE(n_components = 2, verbose = 1, perplexity = 40, n_iter = 300)
#tsne = TSNE(n_components = 2, verbose = 1, n_iter = 300)
tsne_results = tsne.fit_transform(encoded_cont[tsne_ind])
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.003s...
# [t-SNE] Computed neighbors for 10000 samples in 0.540s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.048215
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.583336
# [t-SNE] KL divergence after 300 iterations: 2.649238
# t-SNE done! Time elapsed: 30.82157015800476 seconds

# %%
from sklearn.manifold import TSNE
time_start = time.time()
tsne = TSNE(n_components = 2, verbose = 0, perplexity = 50, n_iter = 300)
#tsne = TSNE(n_components = 2, verbose = 1, n_iter = 300)
tsne_results = tsne.fit_transform(encoded_cont)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 213675 samples in 0.176s...
# [t-SNE] Computed neighbors for 213675 samples in 46.207s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 213675
# [t-SNE] Computed conditional probabilities for sample 2000 / 213675
# [t-SNE] Computed conditional probabilities for sample 3000 / 213675
# [t-SNE] Computed conditional probabilities for sample 4000 / 213675
# [t-SNE] Computed conditional probabilities for sample 5000 / 213675
# [t-SNE] Computed conditional probabilities for sample 6000 / 213675
# [t-SNE] Computed conditional probabilities for sample 7000 / 213675
# [t-SNE] Computed conditional probabilities for sample 8000 / 213675
# [t-SNE] Computed conditional probabilities for sample 9000 / 213675
# [t-SNE] Computed conditional probabilities for sample 10000 / 213675
# [t-SNE] Computed conditional probabilities for sample 11000 / 213675
# [t-SNE] Computed conditional probabilities for sample 12000 / 213675
# [t-SNE] Computed conditional probabilities for sample 13000 / 213675
# [t-SNE] Computed conditional probabilities for sample 14000 / 213675
# [t-SNE] Computed conditional probabilities for sample 15000 / 213675
# [t-SNE] Computed conditional probabilities for sample 16000 / 213675
# [t-SNE] Computed conditional probabilities for sample 17000 / 213675
# [t-SNE] Computed conditional probabilities for sample 18000 / 213675
# [t-SNE] Computed conditional probabilities for sample 19000 / 213675
# [t-SNE] Computed conditional probabilities for sample 20000 / 213675
# [t-SNE] Computed conditional probabilities for sample 21000 / 213675
# [t-SNE] Computed conditional probabilities for sample 22000 / 213675
# [t-SNE] Computed conditional probabilities for sample 23000 / 213675
# [t-SNE] Computed conditional probabilities for sample 24000 / 213675
# [t-SNE] Computed conditional probabilities for sample 25000 / 213675
# [t-SNE] Computed conditional probabilities for sample 26000 / 213675
# [t-SNE] Computed conditional probabilities for sample 27000 / 213675
# [t-SNE] Computed conditional probabilities for sample 28000 / 213675
# [t-SNE] Computed conditional probabilities for sample 29000 / 213675
# [t-SNE] Computed conditional probabilities for sample 30000 / 213675
# [t-SNE] Computed conditional probabilities for sample 31000 / 213675
# [t-SNE] Computed conditional probabilities for sample 32000 / 213675
# [t-SNE] Computed conditional probabilities for sample 33000 / 213675
# [t-SNE] Computed conditional probabilities for sample 34000 / 213675
# [t-SNE] Computed conditional probabilities for sample 35000 / 213675
# [t-SNE] Computed conditional probabilities for sample 36000 / 213675
# [t-SNE] Computed conditional probabilities for sample 37000 / 213675
# [t-SNE] Computed conditional probabilities for sample 38000 / 213675
# [t-SNE] Computed conditional probabilities for sample 39000 / 213675
# [t-SNE] Computed conditional probabilities for sample 40000 / 213675
# [t-SNE] Computed conditional probabilities for sample 41000 / 213675
# [t-SNE] Computed conditional probabilities for sample 42000 / 213675
# [t-SNE] Computed conditional probabilities for sample 43000 / 213675
# [t-SNE] Computed conditional probabilities for sample 44000 / 213675
# [t-SNE] Computed conditional probabilities for sample 45000 / 213675
# [t-SNE] Computed conditional probabilities for sample 46000 / 213675
# [t-SNE] Computed conditional probabilities for sample 47000 / 213675
# [t-SNE] Computed conditional probabilities for sample 48000 / 213675
# [t-SNE] Computed conditional probabilities for sample 49000 / 213675
# [t-SNE] Computed conditional probabilities for sample 50000 / 213675
# [t-SNE] Computed conditional probabilities for sample 51000 / 213675
# [t-SNE] Computed conditional probabilities for sample 52000 / 213675
# [t-SNE] Computed conditional probabilities for sample 53000 / 213675
# [t-SNE] Computed conditional probabilities for sample 54000 / 213675
# [t-SNE] Computed conditional probabilities for sample 55000 / 213675
# [t-SNE] Computed conditional probabilities for sample 56000 / 213675
# [t-SNE] Computed conditional probabilities for sample 57000 / 213675
# [t-SNE] Computed conditional probabilities for sample 58000 / 213675
# [t-SNE] Computed conditional probabilities for sample 59000 / 213675
# [t-SNE] Computed conditional probabilities for sample 60000 / 213675
# [t-SNE] Computed conditional probabilities for sample 61000 / 213675
# [t-SNE] Computed conditional probabilities for sample 62000 / 213675
# [t-SNE] Computed conditional probabilities for sample 63000 / 213675
# [t-SNE] Computed conditional probabilities for sample 64000 / 213675
# [t-SNE] Computed conditional probabilities for sample 65000 / 213675
# [t-SNE] Computed conditional probabilities for sample 66000 / 213675
# [t-SNE] Computed conditional probabilities for sample 67000 / 213675
# [t-SNE] Computed conditional probabilities for sample 68000 / 213675
# [t-SNE] Computed conditional probabilities for sample 69000 / 213675
# [t-SNE] Computed conditional probabilities for sample 70000 / 213675
# [t-SNE] Computed conditional probabilities for sample 71000 / 213675
# [t-SNE] Computed conditional probabilities for sample 72000 / 213675
# [t-SNE] Computed conditional probabilities for sample 73000 / 213675
# [t-SNE] Computed conditional probabilities for sample 74000 / 213675
# [t-SNE] Computed conditional probabilities for sample 75000 / 213675
# [t-SNE] Computed conditional probabilities for sample 76000 / 213675
# [t-SNE] Computed conditional probabilities for sample 77000 / 213675
# [t-SNE] Computed conditional probabilities for sample 78000 / 213675
# [t-SNE] Computed conditional probabilities for sample 79000 / 213675
# [t-SNE] Computed conditional probabilities for sample 80000 / 213675
# [t-SNE] Computed conditional probabilities for sample 81000 / 213675
# [t-SNE] Computed conditional probabilities for sample 82000 / 213675
# [t-SNE] Computed conditional probabilities for sample 83000 / 213675
# [t-SNE] Computed conditional probabilities for sample 84000 / 213675
# [t-SNE] Computed conditional probabilities for sample 85000 / 213675
# [t-SNE] Computed conditional probabilities for sample 86000 / 213675
# [t-SNE] Computed conditional probabilities for sample 87000 / 213675
# [t-SNE] Computed conditional probabilities for sample 88000 / 213675
# [t-SNE] Computed conditional probabilities for sample 89000 / 213675
# [t-SNE] Computed conditional probabilities for sample 90000 / 213675
# [t-SNE] Computed conditional probabilities for sample 91000 / 213675
# [t-SNE] Computed conditional probabilities for sample 92000 / 213675
# [t-SNE] Computed conditional probabilities for sample 93000 / 213675
# [t-SNE] Computed conditional probabilities for sample 94000 / 213675
# [t-SNE] Computed conditional probabilities for sample 95000 / 213675
# [t-SNE] Computed conditional probabilities for sample 96000 / 213675
# [t-SNE] Computed conditional probabilities for sample 97000 / 213675
# [t-SNE] Computed conditional probabilities for sample 98000 / 213675
# [t-SNE] Computed conditional probabilities for sample 99000 / 213675
# [t-SNE] Computed conditional probabilities for sample 100000 / 213675
# [t-SNE] Computed conditional probabilities for sample 101000 / 213675
# [t-SNE] Computed conditional probabilities for sample 102000 / 213675
# [t-SNE] Computed conditional probabilities for sample 103000 / 213675
# [t-SNE] Computed conditional probabilities for sample 104000 / 213675
# [t-SNE] Computed conditional probabilities for sample 105000 / 213675
# [t-SNE] Computed conditional probabilities for sample 106000 / 213675
# [t-SNE] Computed conditional probabilities for sample 107000 / 213675
# [t-SNE] Computed conditional probabilities for sample 108000 / 213675
# [t-SNE] Computed conditional probabilities for sample 109000 / 213675
# [t-SNE] Computed conditional probabilities for sample 110000 / 213675
# [t-SNE] Computed conditional probabilities for sample 111000 / 213675
# [t-SNE] Computed conditional probabilities for sample 112000 / 213675
# [t-SNE] Computed conditional probabilities for sample 113000 / 213675
# [t-SNE] Computed conditional probabilities for sample 114000 / 213675
# [t-SNE] Computed conditional probabilities for sample 115000 / 213675
# [t-SNE] Computed conditional probabilities for sample 116000 / 213675
# [t-SNE] Computed conditional probabilities for sample 117000 / 213675
# [t-SNE] Computed conditional probabilities for sample 118000 / 213675
# [t-SNE] Computed conditional probabilities for sample 119000 / 213675
# [t-SNE] Computed conditional probabilities for sample 120000 / 213675
# [t-SNE] Computed conditional probabilities for sample 121000 / 213675
# [t-SNE] Computed conditional probabilities for sample 122000 / 213675
# [t-SNE] Computed conditional probabilities for sample 123000 / 213675
# [t-SNE] Computed conditional probabilities for sample 124000 / 213675
# [t-SNE] Computed conditional probabilities for sample 125000 / 213675
# [t-SNE] Computed conditional probabilities for sample 126000 / 213675
# [t-SNE] Computed conditional probabilities for sample 127000 / 213675
# [t-SNE] Computed conditional probabilities for sample 128000 / 213675
# [t-SNE] Computed conditional probabilities for sample 129000 / 213675
# [t-SNE] Computed conditional probabilities for sample 130000 / 213675
# [t-SNE] Computed conditional probabilities for sample 131000 / 213675
# [t-SNE] Computed conditional probabilities for sample 132000 / 213675
# [t-SNE] Computed conditional probabilities for sample 133000 / 213675
# [t-SNE] Computed conditional probabilities for sample 134000 / 213675
# [t-SNE] Computed conditional probabilities for sample 135000 / 213675
# [t-SNE] Computed conditional probabilities for sample 136000 / 213675
# [t-SNE] Computed conditional probabilities for sample 137000 / 213675
# [t-SNE] Computed conditional probabilities for sample 138000 / 213675
# [t-SNE] Computed conditional probabilities for sample 139000 / 213675
# [t-SNE] Computed conditional probabilities for sample 140000 / 213675
# [t-SNE] Computed conditional probabilities for sample 141000 / 213675
# [t-SNE] Computed conditional probabilities for sample 142000 / 213675
# [t-SNE] Computed conditional probabilities for sample 143000 / 213675
# [t-SNE] Computed conditional probabilities for sample 144000 / 213675
# [t-SNE] Computed conditional probabilities for sample 145000 / 213675
# [t-SNE] Computed conditional probabilities for sample 146000 / 213675
# [t-SNE] Computed conditional probabilities for sample 147000 / 213675
# [t-SNE] Computed conditional probabilities for sample 148000 / 213675
# [t-SNE] Computed conditional probabilities for sample 149000 / 213675
# [t-SNE] Computed conditional probabilities for sample 150000 / 213675
# [t-SNE] Computed conditional probabilities for sample 151000 / 213675
# [t-SNE] Computed conditional probabilities for sample 152000 / 213675
# [t-SNE] Computed conditional probabilities for sample 153000 / 213675
# [t-SNE] Computed conditional probabilities for sample 154000 / 213675
# [t-SNE] Computed conditional probabilities for sample 155000 / 213675
# [t-SNE] Computed conditional probabilities for sample 156000 / 213675
# [t-SNE] Computed conditional probabilities for sample 157000 / 213675
# [t-SNE] Computed conditional probabilities for sample 158000 / 213675
# [t-SNE] Computed conditional probabilities for sample 159000 / 213675
# [t-SNE] Computed conditional probabilities for sample 160000 / 213675
# [t-SNE] Computed conditional probabilities for sample 161000 / 213675
# [t-SNE] Computed conditional probabilities for sample 162000 / 213675
# [t-SNE] Computed conditional probabilities for sample 163000 / 213675
# [t-SNE] Computed conditional probabilities for sample 164000 / 213675
# [t-SNE] Computed conditional probabilities for sample 165000 / 213675
# [t-SNE] Computed conditional probabilities for sample 166000 / 213675
# [t-SNE] Computed conditional probabilities for sample 167000 / 213675
# [t-SNE] Computed conditional probabilities for sample 168000 / 213675
# [t-SNE] Computed conditional probabilities for sample 169000 / 213675
# [t-SNE] Computed conditional probabilities for sample 170000 / 213675
# [t-SNE] Computed conditional probabilities for sample 171000 / 213675
# [t-SNE] Computed conditional probabilities for sample 172000 / 213675
# [t-SNE] Computed conditional probabilities for sample 173000 / 213675
# [t-SNE] Computed conditional probabilities for sample 174000 / 213675
# [t-SNE] Computed conditional probabilities for sample 175000 / 213675
# [t-SNE] Computed conditional probabilities for sample 176000 / 213675
# [t-SNE] Computed conditional probabilities for sample 177000 / 213675
# [t-SNE] Computed conditional probabilities for sample 178000 / 213675
# [t-SNE] Computed conditional probabilities for sample 179000 / 213675
# [t-SNE] Computed conditional probabilities for sample 180000 / 213675
# [t-SNE] Computed conditional probabilities for sample 181000 / 213675
# [t-SNE] Computed conditional probabilities for sample 182000 / 213675
# [t-SNE] Computed conditional probabilities for sample 183000 / 213675
# [t-SNE] Computed conditional probabilities for sample 184000 / 213675
# [t-SNE] Computed conditional probabilities for sample 185000 / 213675
# [t-SNE] Computed conditional probabilities for sample 186000 / 213675
# [t-SNE] Computed conditional probabilities for sample 187000 / 213675
# [t-SNE] Computed conditional probabilities for sample 188000 / 213675
# [t-SNE] Computed conditional probabilities for sample 189000 / 213675
# [t-SNE] Computed conditional probabilities for sample 190000 / 213675
# [t-SNE] Computed conditional probabilities for sample 191000 / 213675
# [t-SNE] Computed conditional probabilities for sample 192000 / 213675
# [t-SNE] Computed conditional probabilities for sample 193000 / 213675
# [t-SNE] Computed conditional probabilities for sample 194000 / 213675
# [t-SNE] Computed conditional probabilities for sample 195000 / 213675
# [t-SNE] Computed conditional probabilities for sample 196000 / 213675
# [t-SNE] Computed conditional probabilities for sample 197000 / 213675
# [t-SNE] Computed conditional probabilities for sample 198000 / 213675
# [t-SNE] Computed conditional probabilities for sample 199000 / 213675
# [t-SNE] Computed conditional probabilities for sample 200000 / 213675
# [t-SNE] Computed conditional probabilities for sample 201000 / 213675
# [t-SNE] Computed conditional probabilities for sample 202000 / 213675
# [t-SNE] Computed conditional probabilities for sample 203000 / 213675
# [t-SNE] Computed conditional probabilities for sample 204000 / 213675
# [t-SNE] Computed conditional probabilities for sample 205000 / 213675
# [t-SNE] Computed conditional probabilities for sample 206000 / 213675
# [t-SNE] Computed conditional probabilities for sample 207000 / 213675
# [t-SNE] Computed conditional probabilities for sample 208000 / 213675
# [t-SNE] Computed conditional probabilities for sample 209000 / 213675
# [t-SNE] Computed conditional probabilities for sample 210000 / 213675
# [t-SNE] Computed conditional probabilities for sample 211000 / 213675
# [t-SNE] Computed conditional probabilities for sample 212000 / 213675
# [t-SNE] Computed conditional probabilities for sample 213000 / 213675
# [t-SNE] Computed conditional probabilities for sample 213675 / 213675
# [t-SNE] Mean sigma: 0.024529
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 117.058243
# [t-SNE] KL divergence after 300 iterations: 4.952234
# t-SNE done! Time elapsed: 1699.492693901062 seconds

# %% [markdown]
# # HDBSAN clustering
# - The HDBSCAN clustering library: https://hdbscan.readthedocs.io/en/latest/
# - How HDBSCAN works: https://hdbscan.readthedocs.io/en/latest/how_hdbscan_works.html
# - Parameter selection: https://hdbscan.readthedocs.io/en/latest/parameter_selection.html

# %%
import hdbscan as h

# %%
hdb = h.HDBSCAN(min_cluster_size = 100, cluster_selection_method = 'leaf')

# %%
hdb.fit(encoded_cont)
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_method='leaf',
#         core_dist_n_jobs=4, gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=100, min_samples=None, p=None,
#         prediction_data=False)

# %% [markdown]
# Number of clusters

# %%
np.max(hdb.labels_)+1
# Out:
# 18

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[:, 0], 
    y = tsne_results[:, 1],
    hue = hdb.labels_[tsne_ind],
    palette = sns.color_palette("hls", len(np.unique(hdb.labels_[tsne_ind]))),
    legend = "full",
    alpha = 0.7
)

ax.set(title = 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')
plt.savefig('tsne_{}.pdf'.format(time.time()))

# %% [markdown]
# # K-Means Clustering
# Use data encoded into compressed representation to fit a clustering algorithm to group songs.
#
# The number of clusters here maps directly to the number of families of playlists we can generate. Every song will be predicted to belong to a cluster, and the rest of the playlist generated with songs from that cluster.
#
# Read about K-Means:
# - https://stats.stackexchange.com/questions/78313/clustering-inertia-formula-in-scikit-learn
# - https://pythonprogramminglanguage.com/How-is-the-k-nearest-neighbor-algorithm-different-from-k-means-clustering/
# - https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_jobs = -1, n_clusters = 15, n_init = 20, 
                max_iter = 300, random_state = 42, verbose = 0)

kmeans.fit(encoded_cont)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=15, n_init=20, n_jobs=-1, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
cluster_centers = kmeans.cluster_centers_

k_labels = kmeans.labels_

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[:, 0], 
    y = tsne_results[:, 1],
    hue = k_labels[tsne_ind],
    palette = sns.color_palette("hls", len(np.unique(k_labels[tsne_ind]))),
    legend = "full",
    alpha = 0.7
)

ax.set(title = 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

plt.savefig('tsne_{}.pdf'.format(time.time()))

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[:, 0], 
    y = tsne_results[:, 1],
    hue = k_labels[tsne_ind],
    palette = sns.color_palette("hls", len(np.unique(k_labels[tsne_ind]))),
    legend = "full",
    alpha = 0.7
)

ax.set(title = 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

plt.savefig('tsne_{}.pdf'.format(time.time()))

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[:, 0], 
    y = tsne_results[:, 1],
    hue = k_labels,
    palette = sns.color_palette("hls", len(np.unique(k_labels))),
    legend = "full",
    alpha = 0.5
)

ax.set(title = 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

plt.savefig('tsne_{}.pdf'.format(time.time()))

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[tsne_ind, 0], 
    y = tsne_results[tsne_ind, 1],
    hue = k_labels[tsne_ind],
    palette = sns.color_palette("hls", len(np.unique(k_labels[tsne_ind]))),
    legend = "full",
    alpha = 0.5
)

ax.set(title = 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

plt.savefig('tsne_{}.pdf'.format(time.time()))

# %%
# Sizes of fit clusters (num songs in each)
clust, count = np.unique(k_labels, return_counts = True)
for cl, co in zip(clust, count):
    print(cl, ':', co)
# Out:
# 0 : 17434
# 1 : 7447
# 2 : 16620
# 3 : 10878
# 4 : 17170
# 5 : 10155
# 6 : 12500
# 7 : 20787
# 8 : 12098
# 9 : 11318
# 10 : 21551
# 11 : 5942
# 12 : 20485
# 13 : 8673
# 14 : 20617

# %% [markdown]
# # Use clustering to generate playlist from cold start

# %%
np.sum(indicators, axis = 0)
# Out:
# matrix([[12, 84, 81, ..., 35, 75, 17]], dtype=int64)

# %% [markdown]
# Use first playlist as test bed

# %%
playlist = indicators[:, 0].A.reshape((-1,))

playlist_song_ind = list(np.argwhere(playlist == 1).reshape((-1,)))

playlist_song_ids = list(song_ids[playlist_song_ind].reshape((-1,)))
playlist_song_ids
# Out:
# [125250,
#  787744,
#  340039,
#  603984,
#  461894,
#  653897,
#  881533,
#  894661,
#  810569,
#  49614,
#  776037,
#  356319]

# %%
master.loc[playlist_song_ids]
# Out:
#                      artist_name                             artist_uri  \
# song_id
# 125250          Rachael Yamagata  spotify:artist:7w0qj2HiAPIeUcoPogvOZ6
# 787744                 Glee Cast  spotify:artist:0SCbttzoZTnLFebDYmAWCm
# 340039          Sleeping At Last  spotify:artist:0MeLMJJcouYXCymQSHPn8g
# 603984                   Rihanna  spotify:artist:5pKCCKE2ajJHZ9KAiaK11H
# 461894             Mayday Parade  spotify:artist:3WfJ1OtrWI7RViX9DMyEGy
# 653897   The Cinematic Orchestra  spotify:artist:32ogthv0BdaSMPml02X9YB
# 881533   The Cinematic Orchestra  spotify:artist:32ogthv0BdaSMPml02X9YB
# 894661              Shawn Mendes  spotify:artist:7n2wHs1TKAczGzO7Dd2rGr
# 810569              Josef Salvat  spotify:artist:64PJHZDQTPPVBCdwnv22Wz
# 49614               Leon Bridges  spotify:artist:3qnGvpP8Yth1AqSBMqON5x
# 776037                      nilu  spotify:artist:1XplrA4Q9dPFcayYbJqX6K
# 356319               Ryan Amador  spotify:artist:1ihU4zSTmY0qQXhx8jEXWT
#
#                                          track_name  \
# song_id
# 125250                                    Elephants
# 787744   Somewhere Only We Know (Glee Cast Version)
# 340039                                 Chasing Cars
# 603984                                 Close To You
# 461894                              Terrible Things
# 653897                              To Build A Home
# 881533                                    That Home
# 894661                               Never Be Alone
# 810569                                     Diamonds
# 49614                                         River
# 776037                           How to Save a Life
# 356319                                      Instead
#
#                                     album_uri  duration_ms  \
# song_id
# 125250   spotify:album:6KzK9fDNmj7GHFbcE4gVJD       253701
# 787744   spotify:album:6WlzaRoDShdgVgaqJRjyNH       184653
# 340039   spotify:album:0UIIvTTWNB3gRQWFoxoEDh       242564
# 603984   spotify:album:3Q149ZH46Z0f3oDR7vlDYV       223226
# 461894   spotify:album:4eVvdwd6AC7nh9TvJD9XyT       238076
# 653897   spotify:album:5cPHT4yMCfETLRYAoBFcOZ       371320
# 881533   spotify:album:5cPHT4yMCfETLRYAoBFcOZ       103920
# 894661   spotify:album:5wKylB0Zwnxz046O7po25D       215813
# 810569   spotify:album:1excMWyBjh9UJqk2xYZ7o0       247600
# 49614    spotify:album:4svLfrPPk2npPVuI4kXPYg       238560
# 776037   spotify:album:3JymwO9er7CrAoJULoogfq       262500
# 356319   spotify:album:1t1kSv0ySypwFXKgyocRRk       355529
#
#                                        album_name  count  \
# song_id
# 125250       Elephants...Teeth Sinking Into Heart     14
# 787744   Glee: The Music, The Complete Season Two     86
# 340039                             Covers, Vol. 2    401
# 603984                                       ANTI    500
# 461894                                Valdosta EP    339
# 653897                                   Ma Fleur   1593
# 881533                                   Ma Fleur    121
# 894661                                Handwritten    626
# 810569                                 Night Swim     44
# 49614                                 Coming Home    989
# 776037                         How to Save a Life     59
# 356319                                Ryan Amador    117
#
#                                     track_uri  danceability  energy  ...  \
# song_id                                                              ...
# 125250   spotify:track:0y4TKcc7p2H6P0GJlt01EI         0.312  0.2070  ...
# 787744   spotify:track:66mmvchQ4C3LnPzq4DiAI3         0.493  0.5520  ...
# 340039   spotify:track:2d7LPtieXdIYzf7yHPooWd         0.467  0.1570  ...
# 603984   spotify:track:4gFxywaJejXWxo0NjlWzgg         0.494  0.1700  ...
# 461894   spotify:track:3ZjnFYlal0fXN6t61wdxhl         0.285  0.3710  ...
# 653897   spotify:track:54KFQB6N4pn926IUUYZGzK         0.264  0.1220  ...
# 881533   spotify:track:6q4c1vPRZREh7nw3wG7Ixz         0.412  0.1590  ...
# 894661   spotify:track:6wQSrFnJYm3evLsavFeCVT         0.376  0.4660  ...
# 810569   spotify:track:6Hki3HcbeU2c4T72lJjyZ5         0.462  0.3720  ...
# 49614    spotify:track:0NeJjNlprGfZpeX2LQuN6c         0.658  0.1790  ...
# 776037   spotify:track:617EQMgzYFe2THz093j68m         0.366  0.0709  ...
# 356319   spotify:track:2kuFVY6hWX6yavTiWHE3SQ         0.365  0.2600  ...
#
#          instrumentalness  liveness  valence    tempo  time_signature  \
# song_id
# 125250           0.008180    0.0773   0.2780   93.778               4
# 787744           0.000000    0.0969   0.3060   85.973               4
# 340039           0.000001    0.0816   0.2770  108.130               4
# 603984           0.000000    0.1390   0.1450   80.098               4
# 461894           0.003920    0.1040   0.3720  154.989               3
# 653897           0.349000    0.0940   0.0735  148.658               4
# 881533           0.772000    0.0830   0.0389   85.462               4
# 894661           0.000058    0.0781   0.2760  199.835               4
# 810569           0.000452    0.1020   0.2760  169.931               4
# 49614            0.000000    0.1700   0.1910  128.128               4
# 776037           0.000000    0.0936   0.1550   94.502               4
# 356319           0.000000    0.1010   0.2340  161.637               3
#
#                                              artist_genres  artist_popularity  \
# song_id
# 125250              ['acoustic pop', 'folk-pop', 'lilith']                 52
# 787744         ['glee club', 'hollywood', 'post-teen pop']                 80
# 340039    ['ambient worship', 'dreamo', 'folk-pop', 'pop']                 75
# 603984   ['barbadian pop', 'dance pop', 'pop', 'post-te...                 91
# 461894     ['emo', 'neon pop punk', 'pop emo', 'pop punk']                 68
# 653897   ['acid jazz', 'chamber pop', 'downtempo', 'ele...                 65
# 881533   ['acid jazz', 'chamber pop', 'downtempo', 'ele...                 65
# 894661   ['canadian pop', 'pop', 'post-teen pop', 'vira...                 93
# 810569                                       ['gauze pop']                 53
# 49614                             ['modern blues', 'soul']                 75
# 776037                                                  []                 44
# 356319                                                  []                 37
#
#          album_genres  album_popularity  album_release_date
# song_id
# 125250             []                40          2008-10-06
# 787744             []                49                2010
# 340039             []                67          2016-11-04
# 603984             []                58          2016-01-28
# 461894             []                53          2009-10-06
# 653897             []                63          2007-05-07
# 881533             []                63          2007-05-07
# 894661             []                18          2015-04-13
# 810569             []                35          2015-10-23
# 49614              []                70          2015-06-15
# 776037             []                34          2015-05-11
# 356319             []                39          2013-06-28
#
# [12 rows x 25 columns]

# %% [markdown]
# Plot playlist in t-SNE space

# %%
tsne.embedding_.shape
# Out:
# (10000, 2)

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[tsne_ind, 0], 
    y = tsne_results[tsne_ind, 1],
    #hue = k_labels[tsne_ind],
    #palette = sns.color_palette("hls", len(np.unique(k_labels[tsne_ind]))),
    legend = "full",
    color = 'grey',
    alpha = 0.5
)

ax.set(title = 'Main', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

#plt.savefig('tsne_{}.pdf'.format(time.time()))
# Out:
# [Text(0, 0.5, 't-SNE 2'),
#  Text(0.5, 0, 't-SNE 1'),
#  Text(0.5, 1.0, 't-SNE of K-Means clusters of 10,000 songs (MinMax-scaled autoencoder data)')]

# %%
plt.figure(figsize=(10, 8))

ax = sns.scatterplot(
    x = tsne_results[tsne_ind, 0], 
    y = tsne_results[tsne_ind, 1],
    #hue = k_labels[tsne_ind],
    #palette = sns.color_palette("hls", len(np.unique(k_labels[tsne_ind]))),
    legend = "full",
    color = 'grey',
    alpha = 0.15
)

psi = list(np.argwhere(indicators[:, 4].A.reshape((-1,)) == 1).reshape((-1,)))
ax = sns.scatterplot(
    x = tsne_results[psi, 0], 
    y = tsne_results[psi, 1],
    color = 'red',
    alpha = 1.0
)

psi = list(np.argwhere(indicators[:, 1].A.reshape((-1,)) == 1).reshape((-1,)))
ax = sns.scatterplot(
    x = tsne_results[psi, 0], 
    y = tsne_results[psi, 1],
    color = 'blue',
    alpha = 1.0
)

psi = list(np.argwhere(indicators[:, 12].A.reshape((-1,)) == 1).reshape((-1,)))
ax = sns.scatterplot(
    x = tsne_results[psi, 0], 
    y = tsne_results[psi, 1],
    color = 'green',
    alpha = 1.0
)

psi = list(np.argwhere(indicators[:, 3].A.reshape((-1,)) == 1).reshape((-1,)))
ax = sns.scatterplot(
    x = tsne_results[psi, 0], 
    y = tsne_results[psi, 1],
    color = 'orange',
    alpha = 1.0
)

ax.set(title = 'Main', 
       xlabel = 't-SNE 1', ylabel = 't-SNE 2')

plt.savefig('tsne_{}.pdf'.format(time.time()))

# %% [markdown]
# Generate playlist

# %%
encoded_cont[playlist_song_ind, :].shape
# Out:
# (12, 5)

# %%
encoded_cont[playlist_song_ind[0], :]
# Out:
# array([0.01727265, 0.3674057 , 0.29090387, 0.14947325, 0.3388378 ],
#       dtype=float32)

# %%
encoded_cont[playlist_song_ind[0:1], :].shape
# Out:
# (1, 5)

# %%
# Predict label of first song in playlist
lab_pred = int(kmeans.predict(encoded_cont[playlist_song_ind[0:1], :]))

# Get songs in that cluster
cluster_songs_ind = np.argwhere(k_labels == int(kmeans.predict(encoded_cont[playlist_song_ind[0:1], :])))

# %% [markdown]
# Given a set of start songs for the cold start, there are some potential ways of populating a playlist. For each of those songs, predict the cluster to which it belongs, then either:
# - Pull songs from the mode cluster (i.e. the most common), if tied pick a random cluster and get all new songs from there.
# - **Our implementation**: Pull randomly from one of the predicted clusters each time, with probability weighted equal to the number of times each cluster was predicted.
# - Instead of predicting the single cluster of each start song, get its distance to all clusters, sum them up, average them, and use that to determine the closet cluster(s) of the songs as a group, then pull from either the closest one or closest $n$ with some weighting scheme (e.g. by distance).
#
# Should handle running out of songs to sample from, i.e. if we exhaust the cluster when pulling new songs to populate the playlist, but with a reasonably low number of clusters there are so many it seems very unlikely any playlist will be so long it exhausts any cluster.

# %% [markdown]
# Algorithm to use a KMeans clustering model to generate a playlist. Given a fit KMeans and a set of seed songs with which to start the playlist, the algorithm predicts the cluster of each seed song using the model. It then generates a sequence of the cluster from which it will pull each new song in the playlist, weighting the probability of each cluster by the number of seed songs that belongs to that cluster. Iterating through that sequence, it pulls a random song from the respective cluster, removing it from the next iteration to avoid duplicate songs in the new playlist (however unlikely, with the dataset size). Finally, it returns the new songs in the playlist in terms of their indices in the test set and their song id in the master songs table.

# %%
'''
Function to generate a new playlist based on a given set of starting songs
Returns the list new songs, both as their indices in the train set and as song ids in master
Note: returns are exclusive of seed songs, so need to prepend those first if to be included
'''
def generate_playlist(start_songs, clusterer, playlist_length = 20):
    # Ensure proper dimensions of songs: handles list of individual songs or set of songs
    start_clusters = clusterer.predict(np.reshape(start_songs, (len(start_songs), -1)))
    print('Starting songs clusters:', start_clusters)

    # Get count of each start cluster and its respective weight of total
    start_cluster, cluster_count = np.unique(start_clusters, return_counts = True)
    start_cluster, cluster_count = list(start_cluster), list(cluster_count)
    cluster_weight = cluster_count / np.sum(cluster_count)
    print('Cluster, Counts, Weights:', start_cluster, cluster_count, cluster_weight)

    # For each cluster from which we will sample, get indices of all songs in train set
    cluster_song_ind = [np.argwhere(train_labels == c).reshape((-1,)) for c in start_cluster]
    # Flatten component arrays
    print(len(cluster_song_ind), 'clusters with # songs each:', [len(clust) for clust in cluster_song_ind])

    # Sample list of clusters with which to populate playlist
    new_song_clusters = np.random.choice(start_cluster, size = playlist_length, p = cluster_weight)
    print('\nNew song clusters:', new_song_clusters)
    
    new_song_train_inds = np.empty((playlist_length), 'int')
    new_song_ids = np.empty((playlist_length), 'int')

    # For each new song
    print('\nRandom song from each random cluster in order:\ncluster train_ind cluster_size')
    for i, ns_c in enumerate(new_song_clusters):
        # Get index of new song cluster from list of train set song indices of each cluster to use
        ns_c_ind = start_cluster.index(ns_c)

        # Get training set index of a random new song from current cluster
        ns_train_ind = np.random.choice(cluster_song_ind[ns_c_ind], size = 1)[0]
        # Remove this song from the temporary list of cluster songs to avoid repeating songs
        cluster_song_ind[ns_c_ind] = cluster_song_ind[ns_c_ind][cluster_song_ind[ns_c_ind] != ns_train_ind]

        # Add song train set index to list of songs in new playlist
        new_song_train_inds[i] = ns_train_ind

        # Get actual song id from master songs table and add to list of new songs
        new_song_ids[i] = train_songids[ns_train_ind]

        # Print cluster of new song, its index in train, and new length of cluster
        print(ns_c, ns_train_ind, len(cluster_song_ind[ns_c_ind]))

    print('\nNew song train indices:\n', new_song_train_inds)
    print('\nNew song IDs from master table:\n', new_song_ids)
    
    return new_song_train_inds, new_song_ids

# %% [markdown]
# Run the function to showase how the baseline model for playlist generation works, and show the example generated playlist based on a set of previously unseen seed/starter songs.

# %%
# Number of songs with which to seed
songs_seed = 3

# Showcase different ways of passing in songs (list of arrays/vectors, whole array)
#start_songs = [test[i:i+1, :] for i in range(songs_seed)]
start_songs = test[0:songs_seed, :]

# Run function to generate playlist
playlist_train_indices, playlist_song_ids = generate_playlist(start_songs, 20)
# Out:
# Starting songs clusters: [0 0 3]
# Cluster, Counts, Weights: [0, 3] [2, 1] [0.66666667 0.33333333]
# 2 clusters with # songs each: [66979, 175581]
#
# New song clusters: [3 0 3 3 0 0 3 3 3 3 3 3 0 0 0 0 0 3 3 3]
#
# Random song from each random cluster in order:
# cluster train_ind cluster_size
# 3 778403 175580
# 0 373778 66978
# 3 913673 175579
# 3 628419 175578
# 0 353901 66977
# 0 100063 66976
# 3 384855 175577
# 3 323133 175576
# 3 387588 175575
# 3 306768 175574
# 3 183521 175573
# 3 31459 175572
# 0 75990 66975
# 0 890223 66974
# 0 221048 66973
# 0 614152 66972
# 0 698068 66971
# 3 720405 175571
# 3 607844 175570
# 3 552151 175569
#
# New song train indices:
#  [778403 373778 913673 628419 353901 100063 384855 323133 387588 306768
#  183521  31459  75990 890223 221048 614152 698068 720405 607844 552151]
#
# New song IDs from master table:
#  [781791 375439 917610 631163 355467 100504 386561 324567 389300 308130
#  184357  31600  76318 894070 222045 616840 701111 723540 610510 554565]

# %% [markdown]
# Show generated playlist as list of songs with metadata. Our seed/starter songs appear first, then the rest in the sequence in which they were generated.
#
# *Note: the K-Means and algorithm only use numeric values, so the non-numeric data below can be misleading as it was not taken into account.*

# %%
# Playlist as list of songs with metadata
pd.read_pickle('../data/master200.pkl').loc[np.append(test_songids[0:3], playlist_song_ids)]
# Out:
#                                                artist_name  \
# song_id
# 554407                                      Mint Condition
# 774639   Nature Sounds Relaxation: Music for Sleep, Med...
# 239936                                          Brainstorm
# 781791                                       One-Eyed Doll
# 375439                                           El Huervo
# 917610                                           Cathedral
# 631163                                         We As Human
# 355467                                    Jaws Underground
# 100504                                            Cascandy
# 386561                                          Joe Budden
# 324567                                        Oscar D'León
# 389300                                         Itzik Dadya
# 308130                                           Chase Coy
# 184357                                       No Fun At All
# 31600                                         Black Knight
# 76318                                 Black Crown Initiate
# 894070                                         Glass Cloud
# 222045                                              Avalon
# 616840                                           Dick Dale
# 701111                                    Thom Sonny Green
# 723540                                              C-bool
# 610510                                              Tipper
# 554565                                    The Long Winters
#
#                                     artist_uri  \
# song_id
# 554407   spotify:artist:4MT97VeycuegSicrrphisJ
# 774639   spotify:artist:1qzR1EqCmsTDa9AwBLTT4b
# 239936   spotify:artist:6JPBUFrfF5w5whOPk2w0kp
# 781791   spotify:artist:4w2wxHsHxLp64aXeZ9v1nW
# 375439   spotify:artist:2gG1LfmQPkHZNptgVpYlpr
# 917610   spotify:artist:5O7ziOtiFUyRMBJN1J4Tpv
# 631163   spotify:artist:6FFTGpuvFDztqTz4t1Hqy9
# 355467   spotify:artist:0cqwBctx3ja0npObrVSfoU
# 100504   spotify:artist:2jSv6vhlLlg9Urqffm5DwO
# 386561   spotify:artist:1SAugjIcuwNPKS4urSB7A6
# 324567   spotify:artist:1c84wItoiAe1pEbpJMqUmQ
# 389300   spotify:artist:70287pcNpILjcpoBl0soPs
# 308130   spotify:artist:5Obb6ABge8V2JOmkgQm3VY
# 184357   spotify:artist:6usO1o98RY3cUWxqaQxi8O
# 31600    spotify:artist:6eMofDpXdFkeb18OCEBXmq
# 76318    spotify:artist:2mI89QIY20j4ly27G6qA45
# 894070   spotify:artist:31FeV95p1uS4qVjd8yEHJf
# 222045   spotify:artist:0SFwBkGokPRtTX212zO7xo
# 616840   spotify:artist:6Ycrt8OjGSSFihsb0446eg
# 701111   spotify:artist:1qXYLtBA7kceAR3kQETMUk
# 723540   spotify:artist:67VM1TW9hWE9hlVYcmioaH
# 610510   spotify:artist:1soJ22UMyjIw6SYFtoFJwe
# 554565   spotify:artist:6zdwVjGPgGGZ7W5oBcisP2
#
#                                                 track_name  \
# song_id
# 554407                                Definition Of A Band
# 774639   Nature Sounds – Waterfall, Trickling Cascades ...
# 239936                         You Put A Charge In My Life
# 781791                                           Nudie Bar
# 375439                                                Rust
# 917610                       Hopkins (Witchfinder General)
# 631163                                       We Fall Apart
# 355467                                           The Rules
# 100504                                         Four - Flip
# 386561                                                Wake
# 324567                                 El Derecho De Nacer
# 389300                                      Otcha Ani Ohev
# 308130                                          Boundaries
# 184357                                       Suffer Inside
# 31600                                           Headphones
# 76318                            To The Eye That Leads You
# 894070                              How To Survive Suicide
# 222045                     The Dance Temple - Original Mix
# 616840                                         Maria Elena
# 701111                                              Market
# 723540                       Never Go Away - TomoVip Remix
# 610510                                                Usul
# 554565                                            Carparts
#
#                                     album_uri  duration_ms  \
# song_id
# 554407   spotify:album:7a19lFps8uDiFZr1bhJmmY        59866
# 774639   spotify:album:57nnU1noZOVKKR7yzonkWD       228893
# 239936   spotify:album:4tLBJzaV71qm3TyepiEIBy       251733
# 781791   spotify:album:6rxmXoRR5WWmSKQe3682A2       173026
# 375439   spotify:album:10sWEyUUMMS1i26Iaw94lk       297473
# 917610   spotify:album:1Sks1BI0egVhaE9zni8ddf       318280
# 631163   spotify:album:79dn7GARLrAgKx28cwvLea       230786
# 355467   spotify:album:52lCoLmoM1AqGgsYBA94wi       531200
# 100504   spotify:album:3emOirW73LwC74J6jkVmfr       464640
# 386561   spotify:album:2RYsB37cU8Zfx07aea9PrL       250122
# 324567   spotify:album:6ki7SMpym4mUU0j79JlfxP       289761
# 389300   spotify:album:2qNna5IykHcqSsPf50gDyE       230635
# 308130   spotify:album:67b9uskrKBaZ7btc7caW1V       168528
# 184357   spotify:album:5KmC5TsqmPaRx0stEWvsoY       129759
# 31600    spotify:album:3xQoBILxvE8lQTBECojv45       219795
# 76318    spotify:album:2UgZuvWo5nKqhnuDuCOBol       297693
# 894070   spotify:album:1DEq7EuxVxrrTTtGYQwv7T       277468
# 222045   spotify:album:2ukRxIopLZj8Cjiye49N8E       486666
# 616840   spotify:album:57QisiURl0HFTt81uTemSJ       261933
# 701111   spotify:album:4y7Mp3N7lVS9J6ciqzRPh4       164200
# 723540   spotify:album:37lYUAES2OYyb0jCspvnIP       303232
# 610510   spotify:album:1NDZEzDostTj7AhVNY0xNF       231883
# 554565   spotify:album:6gjoy8CLHH6nBHarNUCKJa       245400
#
#                            album_name  count  \
# song_id
# 554407           Definition Of A Band      1
# 774639                  Nature Sounds      1
# 239936            Funky Entertainment      3
# 781791                           Hole      1
# 375439                 Rust B/W Ghost      6
# 917610             The Serpent's Gold      1
# 631163                    We As Human     46
# 355467                    Still Alive      1
# 100504     Collection One Compilation      1
# 386561                  Wake - Single      4
# 324567              Exitos Y Algo Mas      1
# 389300             Lashir Mehaneshama      1
# 308130                    Sun Culture      1
# 184357              EP's Going Steady      1
# 31600                The Young Future      7
# 76318           The Wreckage of Stars      1
# 894070            Perfect War Forever      1
# 222045               The Dance Temple      1
# 616840              Unknown Territory      1
# 701111                   High Anxiety      1
# 723540                  Never Go Away      1
# 610510                        Flunked      1
# 554565   The Worst You Can Do Is Harm      1
#
#                                     track_uri  danceability  energy  ...  \
# song_id                                                              ...
# 554407   spotify:track:4IAWtxmJ13hXTlxwuG77M0         0.434   0.578  ...
# 774639   spotify:track:60QW1IideSuHPbuoz7dfZh         0.096   1.000  ...
# 239936   spotify:track:1r69KR1iUoLfoN4Z44Okca         0.590   0.527  ...
# 781791   spotify:track:63tL5Gza0dbe3zBNIniuOL         0.523   0.930  ...
# 375439   spotify:track:2uA9EGy7KifPvk2F342IvR         0.745   0.762  ...
# 917610   spotify:track:77cgeHw3mJPfKjivt1HRk1         0.312   0.969  ...
# 631163   spotify:track:4tMOesd7zi9cLH7KZh0DcP         0.482   0.544  ...
# 355467   spotify:track:2kVexGVnckELYvAxVau9lo         0.530   0.992  ...
# 100504   spotify:track:0mDfDoK5GBLJ5xQW7zv14f         0.869   0.614  ...
# 386561   spotify:track:2zXLoK2ILY7lR0qq3IESS7         0.506   0.832  ...
# 324567   spotify:track:2VihI15Uwapz0M523UvfEM         0.724   0.785  ...
# 389300   spotify:track:30oYDFsSbiBYxATQ9xvjOt         0.476   0.623  ...
# 308130   spotify:track:2NrK2bUwaKKHsRkBzdfyx2         0.497   0.661  ...
# 184357   spotify:track:1QPO5NV1u4aXI22jkWkFin         0.186   0.937  ...
# 31600    spotify:track:0F4Ywa23lftpcgxI9kkbni         0.752   0.728  ...
# 76318    spotify:track:0aUpfQNHOCkT1QVQhck06L         0.500   0.972  ...
# 894070   spotify:track:6w78pIg11YLTFcQ194U00m         0.485   0.952  ...
# 222045   spotify:track:1ibtUIRE42CeFlcgRHQCxK         0.618   0.863  ...
# 616840   spotify:track:4mPAinbiAcBiazVBnpkKOs         0.190   0.696  ...
# 701111   spotify:track:5R4XgQ9p28l0gKoE4yC3BH         0.642   0.524  ...
# 723540   spotify:track:5btsevgpx5lQIyTCTtVdGR         0.631   0.928  ...
# 610510   spotify:track:4jM4WSNHLd1tJoB56lZKGh         0.734   0.956  ...
# 554565   spotify:track:4IFGbY5w97f6FvZNqNfsYb         0.515   0.773  ...
#
#          instrumentalness  liveness  valence    tempo  time_signature  \
# song_id
# 554407           0.821000    0.0713  0.66200   97.430               3
# 774639           0.918000    0.9770  0.00001  160.678               1
# 239936           0.000000    0.7550  0.73100  144.911               4
# 781791           0.006690    0.3310  0.83700  160.161               4
# 375439           0.862000    0.1390  0.31100   92.493               4
# 917610           0.008850    0.2900  0.22700  137.177               4
# 631163           0.000000    0.1310  0.40400  119.957               4
# 355467           0.832000    0.3400  0.12500  150.018               4
# 100504           0.779000    0.1150  0.25600  125.204               4
# 386561           0.000000    0.0625  0.68000   83.912               4
# 324567           0.000767    0.1990  0.96100  117.806               4
# 389300           0.000000    0.1750  0.19500   82.001               4
# 308130           0.000332    0.1020  0.66900  195.619               4
# 184357           0.000000    0.0853  0.54700  186.308               4
# 31600            0.000000    0.4410  0.79000   98.137               4
# 76318            0.424000    0.1240  0.05360  122.428               4
# 894070           0.591000    0.3060  0.16900  139.907               3
# 222045           0.443000    0.2740  0.08380  143.997               4
# 616840           0.942000    0.3380  0.66700  189.983               3
# 701111           0.614000    0.1090  0.14600   90.025               4
# 723540           0.027500    0.4570  0.18000  128.015               4
# 610510           0.473000    0.0378  0.92100  175.946               4
# 554565           0.000002    0.0785  0.65100  117.018               4
#
#                                              artist_genres  artist_popularity  \
# song_id
# 554407   ['dance pop', 'funk', 'hip pop', 'minneapolis ...                 54
# 774639                          ['environmental', 'sleep']                 34
# 239936                                          ['p funk']                 35
# 781791            ['hard glam', 'steampunk', 'texas punk']                 31
# 375439                                                  []                 45
# 917610   ['death metal', 'doom metal', 'metal', 'sludge...                 33
# 631163   ['christian alternative rock', 'christian hard...                 44
# 355467                                    ['deep full on']                  8
# 100504                                                  []                 24
# 386561   ['battle rap', 'hip hop', 'new jersey rap', 'p...                 55
# 324567   ['boogaloo', 'latin', 'latin jazz', 'mambo', '...                 63
# 389300                                      ['jewish pop']                 35
# 308130           ['alternative pop rock', 'neon pop punk']                 36
# 184357          ['melodic hardcore', 'punk', 'skate punk']                 43
# 31600                                                   []                 30
# 76318                            ['technical death metal']                 36
# 894070   ['djent', 'metalcore', 'progressive metalcore'...                 32
# 222045                              ['psychedelic trance']                 46
# 616840                                      ['surf music']                 47
# 701111                                                  []                 25
# 723540                                      ['polish pop']                 52
# 610510      ['downtempo', 'glitch hop', 'nu skool breaks']                 50
# 554565                                                  []                 40
#
#          album_genres  album_popularity  album_release_date
# song_id
# 554407             []                44          1996-01-01
# 774639             []                32          2011-11-01
# 239936             []                35                1979
# 781791             []                19          2007-02-20
# 375439             []                38          2015-10-05
# 917610             []                18                2004
# 631163             []                47          2011-06-21
# 355467             []                 3          2010-12-16
# 100504             []                 0          2011-05-02
# 386561             []                20          2016-07-07
# 324567             []                26          1992-03-10
# 389300             []                29                2013
# 308130             []                18          2016-06-24
# 184357             []                17                1998
# 31600              []                 0          2013-10-29
# 76318              []                31          2014-09-30
# 894070             []                 0          2013-10-22
# 222045             []                20          2015-12-28
# 616840             []                22                1994
# 701111             []                23          2016-08-19
# 723540             []                 8          2016-04-14
# 610510             []                 0          2017-01-04
# 554565             []                 0                2002
#
# [23 rows x 25 columns]
